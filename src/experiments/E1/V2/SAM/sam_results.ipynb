# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("sam_results.csv", index_col=0)
df
# Out:
#     frame_num  true_targets  sam_detects  sam_targets_in_queue  \
# 0          83             4            7                     4
# 1          84             4            6                     4
# 2          85             4            6                     5
# 3          86             4            6                     5
# 4          87             4            8                     5
# 5          88             4            8                     5
# 6          89             4            6                     4
# 7          90             4            7                     5
# 8          91             4            5                     4
# 9          92             4            5                     4
# 10         93             4            6                     4
# 11         94             4            6                     5
# 12         95             4            7                     5
# 13         96             4            4                     5
# ...

# %%
plt.figure(figsize=(12,4))
plt.plot(df["frame_num"], df["sam_detects"],color="red", label="YOLO detections")
plt.plot(df["frame_num"], df["sam_targets_in_queue"], color="orange", label="All targets in set")
plt.plot(df["frame_num"], df["sam_targets_displayed"],color="blue", label="Displayed targets")
plt.plot(df["frame_num"], df["true_targets"],"-.",color="black", label="True targets count")
plt.xlabel("Frame number")
plt.ylabel("Number of targets")
#plt.yticks([0,1,2])
plt.title("Number of targets in time")
plt.legend()
plt.savefig("sam_det.png",bbox_inches='tight')
plt.show()
