# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("yolo_results.csv", index_col=0)
df
# Out:
#     frame_num  true_targets  yolo_detects  yolo_targets_in_queue  \
# 0          36             4             5                      4
# 1          37             4             4                      4
# 2          38             4             4                      4
# 3          39             4             4                      4
# 4          40             4             4                      4
# 5          41             4             4                      4
# 6          42             4             4                      4
# 7          43             4             4                      4
# 8          44             4             4                      4
# 9          45             4             5                      4
# 10         46             4             5                      4
# 11         47             4             5                      4
# 12         48             4             5                      4
# ...

# %%
plt.figure(figsize=(12,4))
plt.plot(df["frame_num"], df["yolo_detects"],color="red", label="YOLO detections")
plt.plot(df["frame_num"], df["yolo_targets_in_queue"], color="orange", label="All targets in set")
plt.plot(df["frame_num"], df["yolo_targets_displayed"],color="blue", label="Displayed targets")
plt.plot(df["frame_num"], df["true_targets"],"-.",color="black", label="True targets count")
plt.xlabel("Frame number")
plt.ylabel("Number of targets")
#plt.yticks([0,1,2])
plt.title("Number of targets in time")
plt.legend()
plt.savefig("yolo_det.png",bbox_inches='tight')
plt.show()
